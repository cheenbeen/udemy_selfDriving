# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(0)
pts = 500
x = np.linspace(-3, 3, pts)
y = np.sin(x) + np.random.uniform(-0.5, 0.5, pts)

plt.scatter(x,y)

# %%
model = Sequential()
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))

adam = Adam(lr=0.01)

model.compile(loss ='mse', optimizer=adam)

# %%
model.fit(x,y, epochs=50)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 0s 56us/step - loss: 0.2613
# Epoch 2/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.2424
# Epoch 3/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.2298
# Epoch 4/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.2178
# Epoch 5/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.2171
# Epoch 6/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.2125
# Epoch 7/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.2063
# Epoch 8/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1980
# Epoch 9/50
# 500/500 [==============================] - 0s 51us/step - loss: 0.1850
# Epoch 10/50
# 500/500 [==============================] - 0s 64us/step - loss: 0.1738
# Epoch 11/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1664
# Epoch 12/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1657
# Epoch 13/50
# 500/500 [==============================] - 0s 49us/step - loss: 0.1440
# Epoch 14/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1333
# Epoch 15/50
# 500/500 [==============================] - 0s 49us/step - loss: 0.1268
# Epoch 16/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1232
# Epoch 17/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.1245
# Epoch 18/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1153
# Epoch 19/50
# 500/500 [==============================] - 0s 56us/step - loss: 0.1182
# Epoch 20/50
# 500/500 [==============================] - 0s 75us/step - loss: 0.1164
# Epoch 21/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1088
# Epoch 22/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1125
# Epoch 23/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1111
# Epoch 24/50
# 500/500 [==============================] - 0s 49us/step - loss: 0.1104
# Epoch 25/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1119
# Epoch 26/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1121
# Epoch 27/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1114
# Epoch 28/50
# 500/500 [==============================] - 0s 49us/step - loss: 0.1070
# Epoch 29/50
# 500/500 [==============================] - 0s 56us/step - loss: 0.1249
# Epoch 30/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.1179
# Epoch 31/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.1115
# Epoch 32/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.1157
# Epoch 33/50
# 500/500 [==============================] - 0s 53us/step - loss: 0.1095
# Epoch 34/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.1031
# Epoch 35/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1041
# Epoch 36/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.1022
# Epoch 37/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1043
# Epoch 38/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1037
# Epoch 39/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.1035
# Epoch 40/50
# 500/500 [==============================] - 0s 55us/step - loss: 0.1077
# Epoch 41/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1114
# Epoch 42/50
# 500/500 [==============================] - 0s 51us/step - loss: 0.1115
# Epoch 43/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.1060
# Epoch 44/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1011
# Epoch 45/50
# 500/500 [==============================] - 0s 35us/step - loss: 0.1069
# Epoch 46/50
# 500/500 [==============================] - 0s 37us/step - loss: 0.0995
# Epoch 47/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.1008
# Epoch 48/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.0983
# Epoch 49/50
# 500/500 [==============================] - 0s 61us/step - loss: 0.1001
# Epoch 50/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.1073

# %%
predict = model.predict(x)
plt.scatter(x,y)
plt.plot(x, predict, 'ro')
plt.show()
